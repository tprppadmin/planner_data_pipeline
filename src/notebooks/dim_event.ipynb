# %%
import pandas as pd
import requests
from pathlib import Path

# %%
SHAREPOINT_ROOT = "C:/Users/criss/TP Caterers/TCP BI - Documents/Data/planner_data_pipeline/data"

# %%
STAGING_FACT_TASKS_PATH = SHAREPOINT_ROOT / "data" / "staging" / "Fact_Tasks.csv"
